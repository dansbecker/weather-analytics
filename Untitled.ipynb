# %%
import numpy as np
import pandas as pd
import folium
from branca.colormap import linear

station_stats = pd.read_csv('station_stats.csv')
START_YEAR = 1980
END_YEAR = 2020
num_years = END_YEAR - START_YEAR
station_stats['pct_precip_change'] = (100 * station_stats.slope_total_precip_pct).round(2)
station_stats.head()
# Out:
#     station_id  slope_max_temp  slope_min_temp  slope_total_precip_pct  \
# 0  ASN00009021        0.040568        0.001091               -0.004958
# 1  ASN00023034        0.026023        0.025608               -0.003983
# 2  ASN00040043        0.045486        0.026000               -0.014759
# 3  ASN00066037        0.043564        0.040078               -0.002078
# 4  ASN00086282        0.038020        0.017193               -0.000682
#
#    missing_precip_freq  years_zero_reported_precip municipality   lat    lon  \
# 0             0.000000                           0        Perth -32.0  116.0
# 1             0.000067                           0     Adelaide -35.0  139.0
# 2             0.042978                           0     Brisbane -27.0  153.0
# 3             0.000401                           0       Sydney -34.0  151.0
# 4             0.000000                           0    Melbourne -38.0  145.0
#
#     region                 sub-region    country  elevation  pct_precip_change
# 0  Oceania  Australia and New Zealand  Australia       15.0              -0.50
# 1  Oceania  Australia and New Zealand  Australia        2.0              -0.40
# 2  Oceania  Australia and New Zealand  Australia      100.0              -1.48
# 3  Oceania  Australia and New Zealand  Australia        6.0              -0.21
# 4  Oceania  Australia and New Zealand  Australia      113.0              -0.07

# %%
import altair as alt
metric_descs = {'slope_max_temp': 'Annual change (degrees Celsius) in average daily high temp',
                'slope_min_temp': 'Annual change (degrees Celsius) in average daily low temp',
                'pct_precip_change': 'Annual percent change in precipitation',}


metric_units = {'slope_max_temp': '° / year',
                'slope_min_temp': '° / year',
                'pct_precip_change': '% / year',}

field_to_color_by = 'pct_precip_change'
main_map = folium.Map()
colormap = linear.RdYlBu_08.scale(station_stats[field_to_color_by].quantile(0.05),
                                station_stats[field_to_color_by].quantile(0.95))
colormap.add_to(main_map)
metric_desc = metric_descs[field_to_color_by]
metric_unit = metric_units[field_to_color_by]
colormap.caption = metric_desc
colormap.add_to(main_map)
for _, city in station_stats.iterrows():
    sample_data = pd.DataFrame({'x': [1,2,3,4,5,6],
                                'y': [5,4,3,4,5,6]})
    some_chart = alt.Chart(sample_data).mark_line().encode(
        alt.X('x'),
        alt.Y('y')
    ).to_json()

    icon_color = colormap(city[field_to_color_by])
    folium.CircleMarker(location=[city.lat, city.lon],
                tooltip=f"{city.municipality}\n  value: {city[field_to_color_by]}{metric_unit}",
                fill=True,
                fill_color=icon_color,
                color=None,
                fill_opacity=0.7,
                radius=5,
                popup = folium.Popup(max_width=400).add_child(
                                        folium.features.VegaLite(some_chart, width=400, height=300)
                                        )
                ).add_to(main_map)
    
main_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_657956902ad546fea34ed6c7152c1906%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23vega_lite_baa82b3594f44f82acfcee6d6f8829ca%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20400.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20300.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%20%20% ...

# %%
main_map.
# Out:
# False

# %%
hash(json.dumps({'ag': 2}))
# Out:
# -8097745650991910484

# %%
import folium
import json

my_map = folium.Map()
with open('temp.json', 'w') as f:
    json.dump(my_map.to_json(), f)

with open('temp.json', 'r') as f:
    reloaded_map = json.load(f)
# Out:
# Type:        module
# String form: <module 'folium.map' from '/anaconda3/lib/python3.7/site-packages/folium/map.py'>
# File:        /anaconda3/lib/python3.7/site-packages/folium/map.py
# Docstring:   Classes for drawing maps.

# %%
main_map = folium.Map()

field_to_color_by = 'pct_precip_change'
colormap = linear.RdYlBu_08.scale(station_stats[field_to_color_by].quantile(0.05),
                                  station_stats[field_to_color_by].quantile(0.95))
colormap.add_to(main_map)
colormap.caption = "Average % change in precipitation per year"
colormap.add_to(main_map)

for _, city in station_stats.iterrows():
    icon_color = colormap(city[field_to_color_by])
    folium.CircleMarker(location=[city.lat, city.lon],
                        tooltip=f"{city.municipality}\n{field_to_color_by}: {city[field_to_color_by]}",
                        fill=True,
                        fill_color=icon_color,
                        color=None,
                        fill_opacity=0.7,
                        radius=5
                 ).add_to(main_map)


print(hash(str(main_map.to_dict())))
main_map
# Out:
# 397735308923838136
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_378c34151a1a424885888d9d34d4bfab%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_378c34151a1a424885888d9d34d4bfab%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_378c34151a1a424885888d9d34d4bfab%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_378c34151a1a424885888d9d34d4bfab%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
main_map.to_dict()
# Out:
# OrderedDict([('name', 'Map'),
#              ('id', '378c34151a1a424885888d9d34d4bfab'),
#              ('children',
#               OrderedDict([('openstreetmap',
#                             OrderedDict([('name', 'TileLayer'),
#                                          ('id',
#                                           '88ea164bb9de410fb9c81b3b750c959f'),
#                                          ('children', OrderedDict())])),
#                            ('color_map_f483bb551bae4f3b97f96d79ddf125a4',
#                             OrderedDict([('name', 'ColorMap'),
#                                          ('id',
#                                           'f483bb551bae4f3b97f96d79ddf125a4'),
#                                          ('children', OrderedDict())])),
#                            ('circle_marker_b09758c2589d4931b5a2da2fc0884202',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           'b09758c2589d4931b5a2da2fc0884202'),
#                                          ('children',
#                                           OrderedDict([('tooltip_acad979c90d3442b9c48cb167d884e68',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       'acad979c90d3442b9c48cb167d884e68'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_d39d7b096602424c91982bfb73607ec6',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           'd39d7b096602424c91982bfb73607ec6'),
#                                          ('children',
#                                           OrderedDict([('tooltip_c968db35f28e4f0582c32ccb89a0590b',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       'c968db35f28e4f0582c32ccb89a0590b'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_500f18d86f284c07850ad50dd3a0390a',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '500f18d86f284c07850ad50dd3a0390a'),
#                                          ('children',
#                                           OrderedDict([('tooltip_efb9db8354cb4571b5e826c618d0aa2d',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       'efb9db8354cb4571b5e826c618d0aa2d'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_4fe5e606a7b1449c9c11090d8e656811',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '4fe5e606a7b1449c9c11090d8e656811'),
#                                          ('children',
#                                           OrderedDict([('tooltip_e4426896ee3f4494b82a7a9649337b4c',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       'e4426896ee3f4494b82a7a9649337b4c'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_bafc1d2f2378419b92843dc0bc1c2f24',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           'bafc1d2f2378419b92843dc0bc1c2f24'),
#                                          ('children',
#                                           OrderedDict([('tooltip_728fa3b40adf45fab402de70ef0e09dc',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '728fa3b40adf45fab402de70ef0e09dc'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_fc64ca3dfe9d4375a15b8688c9220d22',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           'fc64ca3dfe9d4375a15b8688c9220d22'),
#                                          ('children',
#                                           OrderedDict([('tooltip_5df35be04c024147849fe8149add50cf',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '5df35be04c024147849fe8149add50cf'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker

#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '1d9f36af52ba463e80167d14ec295760'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_6ee974d6f3494172827b8d6840c1c281',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '6ee974d6f3494172827b8d6840c1c281'),
#                                          ('children',
#                                           OrderedDict([('tooltip_b705c95f1d4c4d17bfdb83579e716003',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       'b705c95f1d4c4d17bfdb83579e716003'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_2ed58037f3bc4dc681297280288c3c64',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '2ed58037f3bc4dc681297280288c3c64'),
#                                          ('children',
#                                           OrderedDict([('tooltip_b702e8a4cf7242e190e920edcad3a48d',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       'b702e8a4cf7242e190e920edcad3a48d'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_d268433bf9494324876a553763072494',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           'd268433bf9494324876a553763072494'),
#                                          ('children',
#                                           OrderedDict([('tooltip_ab019f6c0d3e4f5283ff1e2b4c1d9d21',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       'ab019f6c0d3e4f5283ff1e2b4c1d9d21'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_b12c5a1824a540a18280102597bfaf25',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           'b12c5a1824a540a18280102597bfaf25'),
#                                          ('children',
#                                           OrderedDict([('tooltip_4aa18ba43e414d24ba02549d266006f9',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '4aa18ba43e414d24ba02549d266006f9'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_98935b6c33f74022bb077fc8022397ed',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '98935b6c33f74022bb077fc8022397ed'),
#                                          ('children',
#                                           OrderedDict([('tooltip_6aedd71cda6647e28c35918ebb7afbc7',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '6aedd71cda6647e28c35918ebb7afbc7'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_7089f867926f4292a11c99dc10261ff7',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '7089f867926f4292a11c99dc10261ff7'),
#                                          ('children',
#                                           OrderedDict([('tooltip_3252f29ebb834cd396ae5cdb47645622',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '3252f29ebb834cd396ae5cdb47645622'),
#                                                                      ('children',
# ...
#                                          ('id',
#                                           'c5c904abefd14406936902f895757eca'),
#                                          ('children',
#                                           OrderedDict([('tooltip_108f1d17745347fb854841dcc93f03fe',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '108f1d17745347fb854841dcc93f03fe'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_608a09a672624e97be140a4616355f8e',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '608a09a672624e97be140a4616355f8e'),
#                                          ('children',
#                                           OrderedDict([('tooltip_156a7c45a99c49f4988c03bf9627f0af',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '156a7c45a99c49f4988c03bf9627f0af'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_227d19f3f8014ad58db0f3bce07f811e',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '227d19f3f8014ad58db0f3bce07f811e'),
#                                          ('children',
#                                           OrderedDict([('tooltip_ab68a1689d17461ab168a0f2dc7fc2be',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       'ab68a1689d17461ab168a0f2dc7fc2be'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_2ff482ad95d54212a9a379267d15ad97',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '2ff482ad95d54212a9a379267d15ad97'),
#                                          ('children',
#                                           OrderedDict([('tooltip_2a1f2058a08f41108bf73b3dd8e7084e',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '2a1f2058a08f41108bf73b3dd8e7084e'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_b5c7fdbdc79347ac9a32046fbae3a35f',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           'b5c7fdbdc79347ac9a32046fbae3a35f'),
#                                          ('children',
#                                           OrderedDict([('tooltip_63fb1c15b5a24deeb322290e9f43e3d1',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '63fb1c15b5a24deeb322290e9f43e3d1'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_531e13da49a44a77997d141ff9dce6fe',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '531e13da49a44a77997d141ff9dce6fe'),
#                                          ('children',
#                                           OrderedDict([('tooltip_82451eb486f44813b9e17a834da1aff1',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '82451eb486f44813b9e17a834da1aff1'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_43268126af124bb6ae49445efd664b05',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '43268126af124bb6ae49445efd664b05'),
#                                          ('children',
#                                           OrderedDict([('tooltip_a2df6d5e592f484e933a9b57ab416edd',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       'a2df6d5e592f484e933a9b57ab416edd'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_07b6ddd48e7145e7b56b1eb55c76c0fd',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '07b6ddd48e7145e7b56b1eb55c76c0fd'),
#                                          ('children',
#                                           OrderedDict([('tooltip_d0458f0dd1c6412490d34700dd4aafec',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       'd0458f0dd1c6412490d34700dd4aafec'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_fe55d15889e7488c892b9728ecdc7480',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           'fe55d15889e7488c892b9728ecdc7480'),
#                                          ('children',
#                                           OrderedDict([('tooltip_1f8e1e337c684ba2846b5ff8e5c1e78a',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '1f8e1e337c684ba2846b5ff8e5c1e78a'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_271315fdcea64bdbae6a8c6545f74b4a',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '271315fdcea64bdbae6a8c6545f74b4a'),
#                                          ('children',
#                                           OrderedDict([('tooltip_a6c4c6eb1aab4c9c8fa5eb64d27272ae',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       'a6c4c6eb1aab4c9c8fa5eb64d27272ae'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_e7b796090fc74cd0ab8bad29114af3a2',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           'e7b796090fc74cd0ab8bad29114af3a2'),
#                                          ('children',
#                                           OrderedDict([('tooltip_0d5c9634ddfe42b3bfd270ef75f66566',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '0d5c9634ddfe42b3bfd270ef75f66566'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_a85d3b13d28e441584401482cb737fbc',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           'a85d3b13d28e441584401482cb737fbc'),
#                                          ('children',
#                                           OrderedDict([('tooltip_77975b4d74824072ac2927f8221f2037',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '77975b4d74824072ac2927f8221f2037'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_ee1101378b904818a2adfde7ca478f92',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           'ee1101378b904818a2adfde7ca478f92'),
#                                          ('children',
#                                           OrderedDict([('tooltip_fa20ea56fc624deda8ef14c1e424b573',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       'fa20ea56fc624deda8ef14c1e424b573'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_d28ceb7b55d44a6cab82f4f789e41d12',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           'd28ceb7b55d44a6cab82f4f789e41d12'),
#                                          ('children',
#                                           OrderedDict([('tooltip_1488b0318dc84a09a62b229197551fd2',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '1488b0318dc84a09a62b229197551fd2'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_2f3dc748ce564c61a0b2a10a3e0eda84',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '2f3dc748ce564c61a0b2a10a3e0eda84'),
#                                          ('children',
#                                           OrderedDict([('tooltip_1b5b6f11f2474fb5a4c484f862340c43',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '1b5b6f11f2474fb5a4c484f862340c43'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_2326f8b1b1164d5996102ed69f3b65dc',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           '2326f8b1b1164d5996102ed69f3b65dc'),
#                                          ('children',
#                                           OrderedDict([('tooltip_6b168fc65a0c46b69427a2fba5b404ef',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       '6b168fc65a0c46b69427a2fba5b404ef'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('circle_marker_f7ff639f8ecd4744ab5ff0c56d00e9f0',
#                             OrderedDict([('name', 'CircleMarker'),
#                                          ('id',
#                                           'f7ff639f8ecd4744ab5ff0c56d00e9f0'),
#                                          ('children',
#                                           OrderedDict([('tooltip_fd8c9b03d6764d8b9ee53d7cdf4f7cb1',
#                                                         OrderedDict([('name',
#                                                                       'Tooltip'),
#                                                                      ('id',
#                                                                       'fd8c9b03d6764d8b9ee53d7cdf4f7cb1'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))]))]))])

# %%
hash(str(main_map.to_dict()))
# Out:
# -4486183923750422542

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-eb033c5c639f> in <module>()
#       1 import builtins
#       2
# ----> 3 weakref
#
# NameError: name 'weakref' is not defined
